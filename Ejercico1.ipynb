# %% [markdown]
# <a href="https://colab.research.google.com/github/fenixruben28-glitch/vacaciones-app2.0/blob/main/Ejercico1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejercicio 1
x=1
y=3
x==y
# Out:
# False

# %%
print(x)
print(y)
# Out:
# 1
# 3

# %%
print('hello word')
print( "Podemos imprimir variables numericas como x= ",x)
print('Podemos mandar a chingar a su madre a','ivan','martin')
print("y a martin e ivan otra vez \n")
# Out:
# hello word
# Podemos imprimir variables numericas como x=  1
# Podemos mandar a chingar a su madre a ivan martin
# y a martin e ivan otra vez

# %%
value=input("ingresa un numero:")
print(value)
# Out:
# ingresa un numero:4.7
# 4.7

# %%
from types import new_class
new_value=int(float(value))
print(new_value)
# Out:
# 4

# %%
other_value=float(value)
print(other_value)
# Out:
# 4.7

# %%
x<y
# Out:
# True

# %%
x>y
# Out:
# False

# %%
x<=y
# Out:
# True

# %%
x>=y
# Out:
# False

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True
